# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/CV_HW4/yolov7
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CV_HW4/yolov7

# %% [markdown]
# Download data from drive and put in {your_drive_path}/yolov7/data/
#
# [TODO]
# write two TODO functions in {your_drive_path}/yolov7/data/pre_process.py
#
# 1. split_train_val_path --> You need to split all image paths to train and validation in Q1, Q2, and Q3.
#
# 2. select_images --> You need to finish this function to chose better images in Q2 and Q3.

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q1' --train-val-ratio 0.9
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q1', method=1, train_val_ratio=0.9, number_images=200)

# %%
# training command
# !python train.py --project runs/train/Q1 --name ratio_9_1_2
# Out:
# 2023-12-02 07:31:40.398344: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 07:31:40.398401: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 07:31:40.398446: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 07:31:40.407052: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q1/ratio_9_1_2/weights/best.pt" --project runs/test/Q1 --name ratio_9_1_2
# Out:
# Namespace(weights=['./runs/train/Q1/ratio_9_1_2/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q1', name='ratio_9_1_2', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2022-8-2 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# #### Q2

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method 3 --train-val-ratio 0.8
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method=3, train_val_ratio=0.8, number_images=200)

# %%
# training command
# !python train.py --project runs/train/Q2 --name method_3_result_8_2
# Out:
# 2023-12-02 08:19:26.375909: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 08:19:26.375967: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 08:19:26.376006: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 08:19:26.384311: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q2/method_3_result_8_2/weights/best.pt" --project runs/test/Q2 --name method_3_result_8_2
# Out:
# Namespace(weights=['./runs/train/Q2/method_3_result_8_2/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q2', name='method_3_result_8_2', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2022-8-2 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# #### Q3

# %% [markdown]
# ###### 使用positive weight method2 and method3
#
# 打開hyp.scratch.p5
# 更改cls_pw
#
# method3 is better

# %%
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method 2
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method=2, train_val_ratio=0.9)

# %%
# !python train.py --project runs/train/Q3 --name method_2_result_9_1_positive_weight
# Out:
# 2023-11-30 13:10:19.502990: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 13:10:19.503053: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-30 13:10:19.503091: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-30 13:10:19.511710: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q3/method_2_result_9_1_positive_weight/weights/best.pt" --project runs/test/Q3 --name method_2_result_9_1_positive_weight
# Out:
# Namespace(weights=['./runs/train/Q3/method_2_result_9_1_positive_weight/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q3', name='method_2_result_9_1_positive_weight', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2022-8-2 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %% [markdown]
# ###### 使用freeze layer method3
#
# 在train.py時 將--freeze打開 並且輸入要結凍的層數即可

# %%
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method 3 --train-val-ratio 0.9
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method=3, train_val_ratio=0.9)

# %%
# !python train.py --project runs/train/Q3 --freeze 5 --name method_3_result_9_1_freeze
# Out:
# 2023-11-30 09:47:42.989939: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 09:47:42.989995: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-30 09:47:42.990039: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-30 09:47:42.997972: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q3/method_3_result_9_1_freeze/weights/best.pt" --project runs/test/Q3 --name refine
# Out:
# Namespace(weights=['./runs/train/Q3/method_3_result_9_1_freeze/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q3', name='refine', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2022-8-2 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# ###### 使用focal loss method3
#
# 將hyp file裡面的 fl_gamma調整成(1.5) 即可使用focal loss

# %%
# !python train.py --project runs/train/Q3 --name method_3_result_9_1_focal_loss
# Out:
# 2023-11-30 11:52:37.160350: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-30 11:52:37.160418: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-30 11:52:37.160459: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-30 11:52:37.172037: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q3/method_3_result_9_1_focal_loss/weights/best.pt" --project runs/test/Q3 --name method_3_result_9_1_focal_loss
# Out:
# Namespace(weights=['./runs/train/Q3/method_3_result_9_1_focal_loss/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q3', name='method_3_result_9_1_focal_loss', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2022-8-2 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %% [markdown]
# ###### 最好的結果
# method3 + positive weight
# 加上pseudo label
# 但是只能使用200筆資料，過多的資料會讓其學習不佳

# %%
# !python detect.py --weight "./runs/train/Q3/method_3_result_9_1_positive_weight/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/170' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q3/method_3_result_9_1_positive_weight/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/173' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q3/method_3_result_9_1_positive_weight/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/398' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q3/method_3_result_9_1_positive_weight/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/410' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q3/method_3_result_9_1_positive_weight/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/495' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q3/method_3_result_9_1_positive_weight/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/511' --nosave --exist-ok
# Out:
# Namespace(weights=['./runs/train/Q3/method_3_result_9_1_positive_weight/weights/best.pt'], source='./data/CityCam/Q3/170', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=False, nosave=True, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect/Q3', name='pseudo_label', exist_ok=True, no_trace=False)
# YOLOR 🚀 2022-8-2 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# 如果沒有positive weight 的狀況下 Method 2 is better than method 3
#
# But now I want to use positive weight and pseudo label, I use method 3.
#
# 因為我已經有訓練過的best weight: method_3_result_9_1_positive_weight
#
# 所以我直接抽取特定數量的pseduo label 進行訓練

# %%
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q3_whole_data' --method 3 --train-val-ratio 0.9
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q3_whole_data', method=3, train_val_ratio=0.9, number_images=200)

# %%
# !python train.py --weights "./runs/train/Q3/method_3_result_9_1_positive_weight/weights/best.pt" --project runs/train/Q3 --name method_3_result_9_1_pseudo_label_200
# Out:
# 2023-12-02 08:52:50.266167: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 08:52:50.266227: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 08:52:50.266265: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 08:52:50.274286: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q3/method_3_result_9_1_pseudo_label_200/weights/best.pt" --project runs/test/Q3 --name method_3_result_9_1_pseudo_label_200
# Out:
# Namespace(weights=['./runs/train/Q3/method_3_result_9_1_pseudo_label_200_2/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q3', name='method_3_result_9_1_pseudo_label_200_2', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2022-8-2 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...
